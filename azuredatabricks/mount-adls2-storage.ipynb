# %%
storage_account_name = 'rkdatabricks'
client_id = '8754b5a6-be33-4afb-a6de-f4530f2063ad'
tenant_id = '1ed1fae2-9d4a-4ce1-bd63-58e2489101de'
client_secret = '~Gs7Q~9Ij~TiSx4.Rlij.g-2dIg6O.UOwuugr'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.secrets.get(scope='adls2-access-scope',key='adls2-secret')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: &#39;[REDACTED]&#39;</div>

# %%
configs = {
    'fs.azure.account.auth.type': 'OAuth',
    'fs.azure.account.oauth.provider.type': 'org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider',
    'fs.azure.account.oauth2.client.id': f"{client_id}",
    'fs.azure.account.oauth2.client.secret': f'{client_secret}',
    'fs.azure.account.oauth2.client.endpoint': f"https://login.microsoftonline.com/{tenant_id}/oauth2/token"
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
container_name = 'cm-raw'
dbutils.fs.mount(
    source = f"abfss://{container_name}@{storage_account_name}.dfs.core.windows.net",
    mount_point = f"/mnt/cm-test",
    extra_configs = configs
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3728905085820261&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> container_name <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;cm-raw&#39;</span>
# <span class="ansi-green-fg">----&gt; 2</span><span class="ansi-red-fg"> dbutils.fs.mount(
# </span><span class="ansi-green-intense-fg ansi-bold">      3</span>     source <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">f&#34;abfss://{container_name}@{storage_account_name}.dfs.core.windows.net&#34;</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>     mount_point <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">f&#34;/mnt/cm-test&#34;</span><span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>     extra_configs <span class="ansi-blue-fg">=</span> configs
#
# <span class="ansi-green-fg">/databricks/python_shell/dbruntime/dbutils.py</span> in <span class="ansi-cyan-fg">f_with_exception_handling</span><span class="ansi-blue-fg">(*args, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    317</span>                     exc<span class="ansi-blue-fg">.</span>__context__ <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    318</span>                     exc<span class="ansi-blue-fg">.</span>__cause__ <span class="ansi-blue-fg">=</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-fg">--&gt; 319</span><span class="ansi-red-fg">                     </span><span class="ansi-green-fg">raise</span> exc
# <span class="ansi-green-intense-fg ansi-bold">    320</span>
# <span class="ansi-green-intense-fg ansi-bold">    321</span>             <span class="ansi-green-fg">return</span> f_with_exception_handling
#
# <span class="ansi-red-fg">ExecutionError</span>: An error occurred while calling o330.mount.
# : java.rmi.RemoteException: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/cm-test; nested exception is:
# 	java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/cm-test
# 	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:128)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:68)
# 	at com.databricks.backend.daemon.dbutils.DBUtilsCore.mount(DBUtilsCore.scala:739)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
# Caused by: java.lang.IllegalArgumentException: requirement failed: Directory already mounted: /mnt/cm-test
# 	at scala.Predef$.require(Predef.scala:281)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.$anonfun$insertMount$1(MetadataManager.scala:431)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.$anonfun$modifyAndVerify$1(MetadataManager.scala:796)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.withRetries(MetadataManager.scala:577)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.modifyAndVerify(MetadataManager.scala:785)
# 	at com.databricks.backend.daemon.data.server.DefaultMetadataManager.insertMount(MetadataManager.scala:439)
# 	at com.databricks.backend.daemon.data.server.handler.MountHandler.receive(MountHandler.scala:99)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.$anonfun$queryHandlers$1(SessionContext.scala:98)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.$anonfun$queryHandlers$1$adapted(SessionContext.scala:97)
# 	at scala.collection.immutable.List.foreach(List.scala:431)
# 	at com.databricks.backend.daemon.data.server.session.SessionContext.queryHandlers(SessionContext.scala:97)
# 	at com.databricks.backend.daemon.data.server.DbfsServerBackend$$anonfun$receive$3.applyOrElse(DbfsServerBackend.scala:299)
# 	at com.databricks.backend.daemon.data.server.DbfsServerBackend$$anonfun$receive$3.applyOrElse(DbfsServerBackend.scala:258)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$2(ServerBackend.scala:90)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:117)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:117)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$1(ServerBackend.scala:75)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:341)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:435)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:455)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:215)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:95)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:213)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:210)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:19)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:251)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:243)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:19)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:430)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:350)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:19)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:341)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:313)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:19)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:74)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleRPC$2(JettyServer.scala:788)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:788)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:711)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$2(JettyServer.scala:426)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:215)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.sca

# %%
dbutils.fs.ls('/mnt/cm-test')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [FileInfo(path=&#39;dbfs:/mnt/cm-test/cm01FEB2018bhav.csv.gz&#39;, name=&#39;cm01FEB2018bhav.csv.gz&#39;, size=68898),
#  FileInfo(path=&#39;dbfs:/mnt/cm-test/cm01JAN2018bhav.csv.gz&#39;, name=&#39;cm01JAN2018bhav.csv.gz&#39;, size=69671),
#  FileInfo(path=&#39;dbfs:/mnt/cm-test/cm01MAR2018bhav.csv.gz&#39;, name=&#39;cm01MAR2018bhav.csv.gz&#39;, size=67780),
#  FileInfo(path=&#39;dbfs:/mnt/cm-test/cm02FEB2018bhav.csv.gz&#39;, name=&#39;cm02FEB2018bhav.csv.gz&#39;, size=69769),
#  FileInfo(path=&#39;dbfs:/mnt/cm-test/cm02JAN2018bhav.csv.gz&#39;, name=&#39;cm02JAN2018bhav.csv.gz&#39;, size=69376),
#  FileInfo(path=&#39;dbfs:/mnt/cm-test/cm03JAN2018bhav.csv.gz&#39;, name=&#39;cm03JAN2018bhav.csv.gz&#39;, size=69300),
#  FileInfo(path=&#39;dbfs:/mnt/cm-test/c

#  FileInfo(path=&#39;dbfs:/mnt/cm-test/cm30JAN2018bhav.csv.gz&#39;, name=&#39;cm30JAN2018bhav.csv.gz&#39;, size=68829),
#  FileInfo(path=&#39;dbfs:/mnt/cm-test/cm31JAN2018bhav.csv.gz&#39;, name=&#39;cm31JAN2018bhav.csv.gz&#39;, size=69568)]</div>

# %%
dbutils.secrets.help()
# Out:
# <div class = "ansiout">
# Provides utilities for leveraging secrets within notebooks.
# Databricks documentation for more info.
#     <h3></h3><b>get(scope: String, key: String): String</b> -> Gets the string representation of a secret value with scope and key<br /><b>getBytes(scope: String, key: String): byte[]</b> -> Gets the bytes representation of a secret value with scope and key<br /><b>list(scope: String): Seq</b> -> Lists secret metadata for secrets within a scope<br /><b>listScopes: Seq</b> -> Lists secret scopes<br /><br /></div>

# %%
dbutils.secrets.get('adls2-access-scope', 'adls2-secret')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: &#39;[REDACTED]&#39;</div>

# %%
dbutils.secrets.get('db-app-client-id-scope', 'db-app-client-id')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: &#39;[REDACTED]&#39;</div>

# %%
client_id_az_kv = dbutils.secrets.get('db-app-client-id-scope', 'db-app-client-id')
tenant_id_az_kv = dbutils.secrets.get('db-app-client-id-scope', 'db-app-tenant-id')
client_secret_az_kv = dbutils.secrets.get('db-app-client-id-scope', 'db-app-client-secret')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
azure_kv_configs  = {
    'fs.azure.account.auth.type': 'OAuth',
    'fs.azure.account.oauth.provider.type': 'org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider',
    'fs.azure.account.oauth2.client.id':  f'{client_id_az_kv}',
    'fs.azure.account.oauth2.client.secret': f'{client_secret_az_kv}',
    'fs.azure.account.oauth2.client.endpoint': f"https://login.microsoftonline.com/{tenant_id_az_kv}/oauth2/token"
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
container_name = 'cm-raw'
dbutils.fs.mount(
    source = f"abfss://{container_name}@{storage_account_name}.dfs.core.windows.net",
    mount_point = f"/mnt/cm-raw-az-kv",
    extra_configs = azure_kv_configs
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[20]: True</div>

# %%
dbutils.fs.ls('/mnt/cm-raw-az-kv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: [FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm01FEB2018bhav.csv.gz&#39;, name=&#39;cm01FEB2018bhav.csv.gz&#39;, size=68898),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm01JAN2018bhav.csv.gz&#39;, name=&#39;cm01JAN2018bhav.csv.gz&#39;, size=69671),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm01MAR2018bhav.csv.gz&#39;, name=&#39;cm01MAR2018bhav.csv.gz&#39;, size=67780),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm02FEB2018bhav.csv.gz&#39;, name=&#39;cm02FEB2018bhav.csv.gz&#39;, size=69769),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm02JAN2018bhav.csv.gz&#39;, name=&#39;cm02JAN2018bhav.csv.gz&#39;, size=69376),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm03JAN2018bhav.csv.gz&#39;, name=&#39;cm03JAN2018bhav.csv.gz&#39;, size=69300),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm04JAN2018bhav.csv.gz&#39;, name=&#39;cm04JAN2018bhav.csv.gz&#39;, size=69080),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm05FEB2018bhav.csv.gz&#39;, name=&#39;cm05FEB2018bhav.csv.gz&#39;, size=69934),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm05JAN2018bhav.csv.gz&#39;, name=&#39;cm05JAN2018bhav.csv.gz&#39;, size=69488),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm05MAR2018bhav.csv.gz&#39;, name=&#39;cm05MAR2018bhav.csv.gz&#39;, size=68707),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm06FEB2018bhav.csv.gz&#39;, name=&#39;cm06FEB2018bhav.csv.gz&#39;, size=69421),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm06MAR2018bhav.csv.gz&#39;, name=&#39;cm06MAR2018bhav.csv.gz&#39;, size=68538),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm07FEB2018bhav.csv.gz&#39;, name=&#39;cm07FEB2018bhav.csv.gz&#39;, size=68165),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm07MAR2018bhav.csv.gz&#39;, name=&#39;cm07MAR2018bhav.csv.gz&#39;, size=68698),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm08FEB2018bhav.csv.gz&#39;, name=&#39;cm08FEB2018bhav.csv.gz&#39;, size=68549),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm08JAN2018bhav.csv.gz&#39;, name=&#39;cm08JAN2018bhav.csv.gz&#39;, size=70619),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm08MAR2018bhav.csv.gz&#39;, name=&#39;cm08MAR2018bhav.csv.gz&#39;, size=68665),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm09FEB2018bhav.csv.gz&#39;, name=&#39;cm09FEB2018bhav.csv.gz&#39;, size=68611),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm09JAN2018bhav.csv.gz&#39;, name=&#39;cm09JAN2018bhav.csv.gz&#39;, size=69845),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm09MAR2018bhav.csv.gz&#39;, name=&#39;cm09MAR2018bhav.csv.gz&#39;, size=67913),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm10JAN2018bhav.csv.gz&#39;, name=&#39;cm10JAN2018bhav.csv.gz&#39;, size=69414),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm11JAN2018bhav.csv.gz&#39;, name=&#39;cm11JAN2018bhav.csv.gz&#39;, size=69337),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm12FEB2018bhav.csv.gz&#39;, name=&#39;cm12FEB2018bhav.csv.gz&#39;, size=68754),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm12JAN2018bhav.csv.gz&#39;, name=&#39;cm12JAN2018bhav.csv.gz&#39;, size=69761),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm12MAR2018bhav.csv.gz&#39;, name=&#39;cm12MAR2018bhav.csv.gz&#39;, size=68964),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm13MAR2018bhav.csv.gz&#39;, name=&#39;cm13MAR2018bhav.csv.gz&#39;, size=68910),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm14FEB2018bhav.csv.gz&#39;, name=&#39;cm14FEB2018bhav.csv.gz&#39;, size=68846),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm14MAR2018bhav.csv.gz&#39;, name=&#39;cm14MAR2018bhav.csv.gz&#39;, size=67546),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm15FEB2018bhav.csv.gz&#39;, name=&#39;cm15FEB2018bhav.csv.gz&#39;, size=68354),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm15JAN2018bhav.csv.gz&#39;, name=&#39;cm15JAN2018bhav.csv.gz&#39;, size=69537),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm15MAR2018bhav.csv.gz&#39;, name=&#39;cm15MAR2018bhav.csv.gz&#39;, size=68339),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm16FEB2018bhav.csv.gz&#39;, name=&#39;cm16FEB2018bhav.csv.gz&#39;, size=68107),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm16JAN2018bhav.csv.gz&#39;, name=&#39;cm16JAN2018bhav.csv.gz&#39;, size=70064),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm16MAR2018bhav.csv.gz&#39;, name=&#39;cm16MAR2018bhav.csv.gz&#39;, size=68951),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm17JAN2018bhav.csv.gz&#39;, name=&#39;cm17JAN2018bhav.csv.gz&#39;, size=69421),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm18JAN2018bhav.csv.gz&#39;, name=&#39;cm18JAN2018bhav.csv.gz&#39;, size=70112),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm19FEB2018bhav.csv.gz&#39;, name=&#39;cm19FEB2018bhav.csv.gz&#39;, size=68258),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm19JAN2018bhav.csv.gz&#39;, name=&#39;cm19JAN2018bhav.csv.gz&#39;, size=68995),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm19MAR2018bhav.csv.gz&#39;, name=&#39;cm19MAR2018bhav.csv.gz&#39;, size=69084),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm20FEB2018bhav.csv.gz&#39;, name=&#39;cm20FEB2018bhav.csv.gz&#39;, size=67319),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm20MAR2018bhav.csv.gz&#39;, name=&#39;cm20MAR2018bhav.csv.gz&#39;, size=68410),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm21FEB2018bhav.csv.gz&#39;, name=&#39;cm21FEB2018bhav.csv.gz&#39;, size=67707),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm21MAR2018bhav.csv.gz&#39;, name=&#39;cm21MAR2018bhav.csv.gz&#39;, size=68518),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm22FEB2018bhav.csv.gz&#39;, name=&#39;cm22FEB2018bhav.csv.gz&#39;, size=67632),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm22JAN2018bhav.csv.gz&#39;, name=&#39;cm22JAN2018bhav.csv.gz&#39;, size=68656),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm22MAR2018bhav.csv.gz&#39;, name=&#39;cm22MAR2018bhav.csv.gz&#39;, size=68697),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm23FEB2018bhav.csv.gz&#39;, name=&#39;cm23FEB2018bhav.csv.gz&#39;, size=67936),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm23JAN2018bhav.csv.gz&#39;, name=&#39;cm23JAN2018bhav.csv.gz&#39;, size=69103),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm23MAR2018bhav.csv.gz&#39;, name=&#39;cm23MAR2018bhav.csv.gz&#39;, size=69162),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm24JAN2018bhav.csv.gz&#39;, name=&#39;cm24JAN2018bhav.csv.gz&#39;, size=68937),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm25JAN2018bhav.csv.gz&#39;, name=&#39;cm25JAN2018bhav.csv.gz&#39;, size=68906),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm26FEB2018bhav.csv.gz&#39;, name=&#39;cm26FEB2018bhav.csv.gz&#39;, size=68948),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm26MAR2018bhav.csv.gz&#39;, name=&#39;cm26MAR2018bhav.csv.gz&#39;, size=70115),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm27FEB2018bhav.csv.gz&#39;, name=&#39;cm27FEB2018bhav.csv.gz&#39;, size=68223),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm27MAR2018bhav.csv.gz&#39;, name=&#39;cm27MAR2018bhav.csv.gz&#39;, size=68243),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm28FEB2018bhav.csv.gz&#39;, name=&#39;cm28FEB2018bhav.csv.gz&#39;, size=67895),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm28MAR2018bhav.csv.gz&#39;, name=&#39;cm28MAR2018bhav.csv.gz&#39;, size=68799),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm29JAN2018bhav.csv.gz&#39;, name=&#39;cm29JAN2018bhav.csv.gz&#39;, size=69258),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm30JAN2018bhav.csv.gz&#39;, name=&#39;cm30JAN2018bhav.csv.gz&#39;, size=68829),
#  FileInfo(path=&#39;dbfs:/mnt/cm-raw-az-kv/cm31JAN2018bhav.csv.gz&#39;, name=&#39;cm31JAN2018bhav.csv.gz&#39;, size=69568)]</div>
