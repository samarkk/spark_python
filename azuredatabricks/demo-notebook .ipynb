# %%
spark.version
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: &#39;3.1.2&#39;</div>

# %%
# %fs
ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td></tr><tr><td>dbfs:/mnt/</td><td>mnt/</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs
ls  FileStore
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/</td><td>tables/</td><td>0</td></tr></tbody></table></div>

# %%
display
# Out:
# <div class = "ansiout">/**<br /> * Lists the contents of a directory.<br /> * <br /> * Example: display(ls("/mnt/my-folder/"))<br /> * <br /> * The FileInfo object that is returned has the following helper methods:<br /> * val files = ls("/mnt/my-folder/")<br /> * files.map(_.name)    // [myFile, myDir/]<br /> * files.map(_.length)  // [1286, 0]<br /> * files.map(_.path)    // [/mnt/my-folder/myFile, /mnt/my-folder/myDir/]<br /> * files.map(_.isDir)   // [false, true]<br /> * files.map(_.isFile)  // [true, false]<br /> * <br /> * @param dir FileSystem URI<br /> * @return Ordered sequence of FileInfos containing the name and size of each file.<br /> */<br /><b>ls(dir: java.lang.String): scala.collection.Seq</b></div><br />

# %%
# underneath databricks file utilities is used to run the %fs commands
dbutils.fs.ls('/')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [FileInfo(path=&#39;dbfs:/FileStore/&#39;, name=&#39;FileStore/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/databricks-datasets/&#39;, name=&#39;databricks-datasets/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/databricks-results/&#39;, name=&#39;databricks-results/&#39;, size=0)]</div>

# %%
# we can combine python with Databricks FileSystem utilities
for file in dbutils.fs.ls('/'):
    print(file)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">FileInfo(path=&#39;dbfs:/databricks-datasets/&#39;, name=&#39;databricks-datasets/&#39;, size=0)
# FileInfo(path=&#39;dbfs:/databricks-results/&#39;, name=&#39;databricks-results/&#39;, size=0)
# </div>

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
# ...

# %%
#notebook utilities
dbutils.notebook.help()
# Out:
# <div class = "ansiout">
# The notebook module.
#   <h3></h3><b>exit(value: String): void</b> -> This method lets you exit a notebook with a value<br /><b>run(path: String, timeoutSeconds: int, arguments: Map): String</b> -> This method runs a notebook and returns its exit value<br /><br /></div>

# %%
# see more information on the notebook run method
dbutils.notebook.help('run')
# Out:
# <div class = "ansiout">/**<br /> * This method runs a notebook and returns its exit value. The notebook will run<br /> * in the current cluster by default.<br /> * <br /> * @param path relative path to the notebook, e.g. ../path/to/notebook<br /> * @param timeoutSeconds timeout in seconds for the called notebook. If the run failed<br /> *                       to finish within this time, this method will throw an exception.<br /> *                       Note that currently, if the Databricks web application is down<br /> *                       for more than 10 minutes, the run will fail regardless of this<br /> *                       parameter.<br /> * @param arguments string map of arguments to pass to the notebook<br /> * <br /> * @return the string returned by dbutils.notebook.exit() or null<br /> * @throws WorkflowException if the notebook run did not complete successfully<br /> */<br /><b>run(path: java.lang.String, timeoutSeconds: int, arguments: scala.collection.Map): java.l
# ...

# %%
dbutils.notebook.run('./child_notebook', 0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: &#39;10&#39;</div>

# %%
dbutils.widgets.removeAll()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.notebook.run('./child_notebook',0,{'textinput': 'called from the main notebook'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: &#39;10&#39;</div>

# %%
notebook_run_result  = dbutils.notebook.run('./child_notebook',0,{'textinput': 'called from the main notebook'})
notebook_run_result
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: &#39;10&#39;</div>

# %%
# %run "./child_notebook"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">hey, i am the child notebook and as of now i am only going to be used to demo being called from another notebook
# </div>
# <div class = "ansiout"><b>dbutils.widgets</b> provides utilities for working with notebook widgets. You can create
# different types of widgets and get their bound value.
#
# For more info about a method, use <b>dbutils.widgets.help("methodName")</b>.
# ...

# %%
print(par1_val)
print(par2_val)
a_simple_function_to_test(10, 100)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">parameter 1 value
# parameter 2 value
# Out[16]: 110</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
# ...

# %%
for x in ['val1 from main notebook', 'val 2 from main notebook', 'val 3 from main notebook']:
    dbutils.notebook.run('./child_notebook',0, {'textinput': x})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# 10

# %%
#child notebook multiple widgets exit
# we can provide the multiple parameters as a map
# and we should have the target notebook - the child_nb_multipl_widgets_nb use these provided values
c_nb_m_w_exit = dbutils.notebook.run('./child_nb_multiple_widgets',0,{'month': '9', 'year': '2019', 'day': '23'})
print(c_nb_m_w_exit)
# mw_notebook_run_result  = dbutils.notebook.run('./child_nb_multiple_widgets',0,{'month': 'called from the main notebook'})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">child_db_multiple_widgets_exit
# </div>

# %%
stocks_exit_nb = dbutils.notebook.run('./stocksapp/stocks_load_incr_nb', 0,
                                     {'year':'2021','month': '10', 'day': '22'})
print(stocks_exit_nb)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">success
# </div>

# %%
# library utilities - advised to use %pip magic command
# %pip install scipy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-36527035-7e2c-4fb3-ae7d-fe503f14b0cc/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# </div>

# %%
# %pip install matplotlib
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the &#39;/local_disk0/.ephemeral_nfs/envs/pythonEnv-36527035-7e2c-4fb3-ae7d-fe503f14b0cc/bin/python -m pip install --upgrade pip&#39; command.
# Python interpreter will be restarted.
# </div>
